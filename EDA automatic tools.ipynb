# %% [markdown]
# # D tale

# %%
pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\lglv\anaconda3\lib\site-packages (2.8.1)
# Requirement already satisfied: certifi; python_version > "3.0" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (2022.6.15)
# Requirement already satisfied: scipy==1.7.3; python_version == "3.7" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.7.3)
# Requirement already satisfied: xlrd in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.2.0)
# Requirement already satisfied: dash>=2.0.0; python_version > "3.6" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (2.6.2)
# Requirement already satisfied: Flask; python_version >= "3.7" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.0.2)
# Requirement already satisfied: squarify in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: cycler; python_version > "3.0" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.10.0)
# Requirement already satisfied: matplotlib==3.5.3; python_version == "3.7" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (3.5.3)
# Requirement already satisfied: dash-colorscales in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: itsdangerous; python_version >= "3.7" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: dash-daq in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.5.0)
# Requirement already satisfied: pandas in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.3.5)
# Requirement already satisfied: plotly>=5.0.0; python_version >= "3.6" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (5.10.0)
# Requirement already satisfied: lz4; python_version > "3.0" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (4.0.2)
# Requirement already satisfied: et-xmlfile; python_version >= "3.6" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.0.1)
# Requirement already satisfied: dash-bootstrap-components; python_version > "3.0" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.2.1)
# Requirement already satisfied: missingno<=0.4.2 in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.4.2)
# Requirement already satisfied: strsimpy in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: seaborn; python_version > "3.6" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.9.0)
# Requirement already satisfied: flask-ngrok; python_version > "3.0" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: scikit-learn==1.0.2; python_version == "3.7" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.0.2)
# Requirement already satisfied: networkx==2.6.3; python_version == "3.7" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (2.6.3)
# Requirement already satisfied: statsmodels==0.12.2; python_version == "3.7" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.12.2)
# Requirement already satisfied: numpy; python_version >= "3.0" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.21.6)
# Requirement already satisfied: requests; python_version >= "3.6" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (2.21.0)
# Requirement already satisfied: future>=0.14.0 in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.17.1)
# Requirement already satisfied: six in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.12.0)
# Requirement already satisfied: Flask-Compress in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (1.13)
# Requirement already satisfied: packaging<=21.0; python_version == "3.7" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (19.0)
# Requirement already satisfied: kaleido; python_version > "3.6" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: xarray; python_version >= "3.0" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (0.20.2)
# Requirement already satisfied: openpyxl; python_version >= "3.0" in c:\users\lglv\anaconda3\lib\site-packages (from dtale) (2.6.1)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\lglv\anaconda3\lib\site-packages (from dash>=2.0.0; python_version > "3.6"->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\lglv\anaconda3\lib\site-packages (from dash>=2.0.0; python_version > "3.6"->dtale) (5.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\lglv\anaconda3\lib\site-packages (from dash>=2.0.0; python_version > "3.6"->dtale) (2.0.0)
# Requirement already satisfied: Werkzeug>=0.14 in c:\users\lglv\anaconda3\lib\site-packages (from Flask; python_version >= "3.7"->dtale) (0.14.1)
# Requirement already satisfied: click>=5.1 in c:\users\lglv\anaconda3\lib\site-packages (from Flask; python_version >= "3.7"->dtale) (7.0)
# Requirement already satisfied: Jinja2>=2.10 in c:\users\lglv\anaconda3\lib\site-packages (from Flask; python_version >= "3.7"->dtale) (2.10)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib==3.5.3; python_version == "3.7"->dtale) (4.37.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib==3.5.3; python_version == "3.7"->dtale) (1.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib==3.5.3; python_version == "3.7"->dtale) (2.8.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib==3.5.3; python_version == "3.7"->dtale) (2.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib==3.5.3; python_version == "3.7"->dtale) (9.2.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lglv\anaconda3\lib\site-packages (from pandas->dtale) (2018.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\lglv\anaconda3\lib\site-packages (from plotly>=5.0.0; python_version >= "3.6"->dtale) (8.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\lglv\anaconda3\lib\site-packages (from scikit-learn==1.0.2; python_version == "3.7"->dtale) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lglv\anaconda3\lib\site-packages (from scikit-learn==1.0.2; python_version == "3.7"->dtale) (3.1.0)
# Requirement already satisfied: patsy>=0.5 in c:\users\lglv\anaconda3\lib\site-packages (from statsmodels==0.12.2; python_version == "3.7"->dtale) (0.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\lglv\anaconda3\lib\site-packages (from requests; python_version >= "3.6"->dtale) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\lglv\anaconda3\lib\site-packages (from requests; python_version >= "3.6"->dtale) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\lglv\anaconda3\lib\site-packages (from requests; python_version >= "3.6"->dtale) (1.24.1)
# Requirement already satisfied: brotli in c:\users\lglv\anaconda3\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: typing-extensions>=3.7; python_version < "3.8" in c:\users\lglv\anaconda3\lib\site-packages (from xarray; python_version >= "3.0"->dtale) (4.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\lglv\anaconda3\lib\site-packages (from xarray; python_version >= "3.0"->dtale) (0.0.0)
# Requirement already satisfied: jdcal in c:\users\lglv\anaconda3\lib\site-packages (from openpyxl; python_version >= "3.0"->dtale) (1.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\lglv\anaconda3\lib\site-packages (from Jinja2>=2.10->Flask; python_version >= "3.7"->dtale) (1.1.1)
# Requirement already satisfied: setuptools in c:\users\lglv\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib==3.5.3; python_version == "3.7"->dtale) (40.8.0)
# Requirement already satisfied: zipp>=0.3.2 in c:\users\lglv\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->xarray; python_version >= "3.0"->dtale) (0.3.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('blackFriday_test.csv')
df.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-S1DNP07G:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading https://files.pythonhosted.org/packages/6f/ab/cbf21c0b3b980a183343a8ec71869a3e54bddd03486178a369aefac89be7/sweetviz-2.1.4-py3-none-any.whl (15.1MB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\lglv\anaconda3\lib\site-packages (from sweetviz) (1.21.6)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\lglv\anaconda3\lib\site-packages (from sweetviz) (1.3.5)
# Collecting jinja2>=2.11.1 (from sweetviz)
#   Using cached https://files.pythonhosted.org/packages/bc/c3/f068337a370801f372f2f8f6bad74a5c140f6fda3d9de154052708dd3c65/Jinja2-3.1.2-py3-none-any.whl
# Requirement already satisfied: scipy>=1.3.2 in c:\users\lglv\anaconda3\lib\site-packages (from sweetviz) (1.7.3)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\lglv\anaconda3\lib\site-packages (from sweetviz) (3.5.3)
# Collecting importlib-resources>=1.2.0 (from sweetviz)
#   Downloading https://files.pythonhosted.org/packages/d3/91/4df247dd4da18b72b5bbabe1fa2b85029c34e1d6f0afdd6329d15d6bf2b5/importlib_resources-5.9.0-py3-none-any.whl
# Collecting tqdm>=4.43.0 (from sweetviz)
#   Using cached https://files.pythonhosted.org/packages/47/bb/849011636c4da2e44f1253cd927cfb20ada4374d8b3a4e425416e84900cc/tqdm-4.64.1-py2.py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lglv\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2.8.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lglv\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2018.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lglv\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.37.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.2.0)
# Collecting zipp>=3.1.0; python_version < "3.10" (from importlib-resources>=1.2.0->sweetviz)
#   Using cached https://files.pythonhosted.org/packages/f0/36/639d6742bcc3ffdce8b85c31d79fcfae7bb04b95f0e5c4c6f8b206a038cc/zipp-3.8.1-py3-none-any.whl
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\lglv\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\lglv\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (1.12.0)
# Requirement already satisfied: setuptools in c:\users\lglv\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib>=3.1.3->sweetviz) (40.8.0)
# Installing collected packages: jinja2, zipp, importlib-resources, tqdm, sweetviz
#   Found existing installation: Jinja2 2.10
#     Uninstalling Jinja2-2.10:
#       Successfully uninstalled Jinja2-2.10
#   Found existing installation: zipp 0.3.3
#     Uninstalling zipp-0.3.3:
#       Successfully uninstalled zipp-0.3.3
#   Found existing installation: tqdm 4.31.1
#     Uninstalling tqdm-4.31.1:
#       Successfully uninstalled tqdm-4.31.1
# Successfully installed importlib-resources-5.9.0 jinja2-3.1.2 sweetviz-2.1.4 tqdm-4.64.1 zipp-3.8.1
# Note: you may need to restart the kernel to use updated packages.
# dtale 2.8.1 has requirement packaging<=21.0; python_version == "3.7", but you'll have packaging 21.3 which is incompatible.
# dtale 2.8.1 has requirement statsmodels==0.12.2; python_version == "3.7", but you'll have statsmodels 0.13.2 which is incompatible.
# dash 2.6.2 has requirement Flask>=1.0.4, but you'll have flask 1.0.2 which is incompatible.

# %% [markdown]
# # Sweetviz

# %%
import sweetviz as swv
report = swv.analyze(df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
report.show_html('sweet_report.html')
# Out:
# Report sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# # Klib

# %%
pip install klib
# Out:
# Collecting klib
#   Downloading https://files.pythonhosted.org/packages/8c/f1/4d25aa6cf418f09ec61ef788065e15882dafb0b356d8e01d5ba474efad1d/klib-1.0.1-py3-none-any.whl
# Requirement already satisfied: scipy<2.0.0,>=1.1.0 in c:\users\lglv\anaconda3\lib\site-packages (from klib) (1.7.3)
# Collecting seaborn<0.12.0,>=0.11.1 (from klib)
#   Using cached https://files.pythonhosted.org/packages/10/5b/0479d7d845b5ba410ca702ffcd7f2cd95a14a4dfff1fde2637802b258b9b/seaborn-0.11.2-py3-none-any.whl
# Requirement already satisfied: numpy<2.0.0,>=1.16.3 in c:\users\lglv\anaconda3\lib\site-packages (from klib) (1.21.6)
# Requirement already satisfied: matplotlib<4.0.0,>=3.0.3 in c:\users\lglv\anaconda3\lib\site-packages (from klib) (3.5.3)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in c:\users\lglv\anaconda3\lib\site-packages (from klib) (3.1.2)
# Requirement already satisfied: pandas<2.0.0,>=1.1.2 in c:\users\lglv\anaconda3\lib\site-packages (from klib) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (4.37.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (1.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\lglv\anaconda3\lib\site-packages (from matplotlib<4.0.0,>=3.0.3->klib) (2.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lglv\anaconda3\lib\site-packages (from Jinja2<4.0.0,>=3.0.3->klib) (2.1.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lglv\anaconda3\lib\site-packages (from pandas<2.0.0,>=1.1.2->klib) (2018.9)
# Requirement already satisfied: six>=1.5 in c:\users\lglv\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.0.3->klib) (1.12.0)
# Requirement already satisfied: setuptools in c:\users\lglv\anaconda3\lib\site-packages (from kiwisolver>=1.0.1->matplotlib<4.0.0,>=3.0.3->klib) (40.8.0)
# Installing collected packages: seaborn, klib
#   Found existing installation: seaborn 0.9.0
#     Uninstalling seaborn-0.9.0:
#       Successfully uninstalled seaborn-0.9.0
# Successfully installed klib-1.0.1 seaborn-0.11.2
# Note: you may need to restart the kernel to use updated packages.
# dtale 2.8.1 has requirement packaging<=21.0; python_version == "3.7", but you'll have packaging 21.3 which is incompatible.
# dtale 2.8.1 has requirement statsmodels==0.12.2; python_version == "3.7", but you'll have statsmodels 0.13.2 which is incompatible.

# %%
import klib

# %%
# klib.describe - functions for visualizing datasets
# klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
# klib.corr_mat(df) # returns a color-encoded correlation matrix
# klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
# klib.dist_plot(df) # returns a distribution plot for every numeric feature
# klib.missingval_plot(df) # returns a figure containing information about missing values

# %%
klib.cat_plot(df)
# Out:
# GridSpec(6, 5)

# %%
klib.corr_mat(df)
# Out:
# <style type="text/css">
# #T_52dfb_row0_col0, #T_52dfb_row0_col2, #T_52dfb_row0_col3, #T_52dfb_row0_col4, #T_52dfb_row0_col5, #T_52dfb_row1_col1, #T_52dfb_row1_col2, #T_52dfb_row1_col5, #T_52dfb_row2_col0, #T_52dfb_row2_col1, #T_52dfb_row2_col2, #T_52dfb_row2_col3, #T_52dfb_row2_col4, #T_52dfb_row2_col5, #T_52dfb_row3_col0, #T_52dfb_row3_col2, #T_52dfb_row3_col3, #T_52dfb_row3_col4, #T_52dfb_row3_col5, #T_52dfb_row4_col0, #T_52dfb_row4_col2, #T_52dfb_row4_col3, #T_52dfb_row4_col4, #T_52dfb_row4_col5, #T_52dfb_row5_col0, #T_52dfb_row5_col1, #T_52dfb_row5_col2, #T_52dfb_row5_col3, #T_52dfb_row5_col4, #T_52dfb_row5_col5 {
#   color: None;
# }
# #T_52dfb_row0_col1, #T_52dfb_row1_col0, #T_52dfb_row1_col3, #T_52dfb_row1_col4, #T_52dfb_row3_col1, #T_52dfb_row4_col1 {
#   color: #FF3344;
# }
# </style>
# <table id="T_52dfb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >User_ID</th>
#       <th class="col_heading level0 col1" >Occupation</th>
#       <th class="col_heading level0 col2" >Marital_Status</th>
#       <th class="col_heading level0 col3" >Product_Category_1</th>
#       <th class="col_heading level0 col4" >Product_Category_2</th>
#       <th class="col_heading level0 col5" >Product_Category_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52dfb_level0_row0" class="row_heading level0 row0" >User_ID</th>
#       <td id="T_52dfb_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_52dfb_row0_col1" class="data row0 col1" >-0.02</td>
#       <td id="T_52dfb_row0_col2" class="data row0 col2" >0.02</td>
#       <td id="T_52dfb_row0_col3" class="data row0 col3" >0.01</td>
#       <td id="T_52dfb_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_52dfb_row0_col5" class="data row0 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_52dfb_level0_row1" class="row_heading level0 row1" >Occupation</th>
#       <td id="T_52dfb_row1_col0" class="data row1 col0" >-0.02</td>
#       <td id="T_52dfb_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_52dfb_row1_col2" class="data row1 col2" >0.02</td>
#       <td id="T_52dfb_row1_col3" class="data row1 col3" >-0.01</td>
#       <td id="T_52dfb_row1_col4" class="data row1 col4" >-0.00</td>
#       <td id="T_52dfb_row1_col5" class="data row1 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_52dfb_level0_row2" class="row_heading level0 row2" >Marital_Status</th>
#       <td id="T_52dfb_row2_col0" class="data row2 col0" >0.02</td>
#       <td id="T_52dfb_row2_col1" class="data row2 col1" >0.02</td>
#       <td id="T_52dfb_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_52dfb_row2_col3" class="data row2 col3" >0.02</td>
#       <td id="T_52dfb_row2_col4" class="data row2 col4" >0.02</td>
#       <td id="T_52dfb_row2_col5" class="data row2 col5" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_52dfb_level0_row3" class="row_heading level0 row3" >Product_Category_1</th>
#       <td id="T_52dfb_row3_col0" class="data row3 col0" >0.01</td>
#       <td id="T_52dfb_row3_col1" class="data row3 col1" >-0.01</td>
#       <td id="T_52dfb_row3_col2" class="data row3 col2" >0.02</td>
#       <td id="T_52dfb_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_52dfb_row3_col4" class="data row3 col4" >0.54</td>
#       <td id="T_52dfb_row3_col5" class="data row3 col5" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_52dfb_level0_row4" class="row_heading level0 row4" >Product_Category_2</th>
#       <td id="T_52dfb_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_52dfb_row4_col1" class="data row4 col1" >-0.00</td>
#       <td id="T_52dfb_row4_col2" class="data row4 col2" >0.02</td>
#       <td id="T_52dfb_row4_col3" class="data row4 col3" >0.54</td>
#       <td id="T_52dfb_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_52dfb_row4_col5" class="data row4 col5" >0.54</td>
#     </tr>
#     <tr>
#       <th id="T_52dfb_level0_row5" class="row_heading level0 row5" >Product_Category_3</th>
#       <td id="T_52dfb_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_52dfb_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_52dfb_row5_col2" class="data row5 col2" >0.02</td>
#       <td id="T_52dfb_row5_col3" class="data row5 col3" >0.23</td>
#       <td id="T_52dfb_row5_col4" class="data row5 col4" >0.54</td>
#       <td id="T_52dfb_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
klib.corr_plot(df)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(df)
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='Product_Category_3', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %%
# klib.clean - functions for cleaning datasets
# klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
# klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
# klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
# klib.drop_missing(df) # drops missing values, also called in data_cleaning()
# klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
# klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information

# %%
klib.data_cleaning(df)
# Out:
# Long column names detected (>25 characters). Consider renaming the following columns ['stay_in_current_city_years'].
# Shape of cleaned data: (233599, 11)Remaining NAs: 234906
#
# Changes:
# Dropped rows: 0
#      of which 0 duplicates. (Rows: [])
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 14.32 MB (-73.06%)
#         user_id product_id gender    age  occupation city_category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                              4+               1                   5
# 3                              4+               1                   4
# 4                               1               0                   4
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         product_category_2  product_category_3
# 0                     11.0                <NA>
# 1                      5.0                <NA>
# 2                     14.0                <NA>
# 3                      9.0                <NA>
# 4                      5.0                12.0
# ...                    ...                 ...
# 233594                <NA>                <NA>
# 233595                 8.0                <NA>
# 233596                 5.0                12.0
# 233597                16.0                <NA>
# 233598                 5.0                <NA>
#
# [233599 rows x 11 columns]

# %%
klib.clean_column_names(df)
# Out:
# Long column names detected (>25 characters). Consider renaming the following columns ['stay_in_current_city_years'].
#         user_id product_id gender    age  occupation city_category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                              4+               1                   5
# 3                              4+               1                   4
# 4                               1               0                   4
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         product_category_2  product_category_3
# 0                     11.0                 NaN
# 1                      5.0                 NaN
# 2                     14.0                 NaN
# 3                      9.0                 NaN
# 4                      5.0                12.0
# ...                    ...                 ...
# 233594                 NaN                 NaN
# 233595                 8.0                 NaN
# 233596                 5.0                12.0
# 233597                16.0                 NaN
# 233598                 5.0                 NaN
#
# [233599 rows x 11 columns]

# %%
klib.convert_datatypes(df)
# Out:
#         user_id product_id gender    age  occupation city_category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                              4+               1                   5
# 3                              4+               1                   4
# 4                               1               0                   4
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         product_category_2  product_category_3
# 0                     11.0                <NA>
# 1                      5.0                <NA>
# 2                     14.0                <NA>
# 3                      9.0                <NA>
# 4                      5.0                12.0
# ...                    ...                 ...
# 233594                <NA>                <NA>
# 233595                 8.0                <NA>
# 233596                 5.0                12.0
# 233597                16.0                <NA>
# 233598                 5.0                <NA>
#
# [233599 rows x 11 columns]

# %%
klib.drop_missing(df)
# Out:
#         user_id product_id gender    age  occupation city_category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                              4+               1                   5
# 3                              4+               1                   4
# 4                               1               0                   4
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         product_category_2  product_category_3
# 0                     11.0                 NaN
# 1                      5.0                 NaN
# 2                     14.0                 NaN
# 3                      9.0                 NaN
# 4                      5.0                12.0
# ...                    ...                 ...
# 233594                 NaN                 NaN
# 233595                 8.0                 NaN
# 233596                 5.0                12.0
# 233597                16.0                 NaN
# 233598                 5.0                 NaN
#
# [233599 rows x 11 columns]

# %%
klib.mv_col_handling(df)
# Out:
#         user_id product_id gender    age  occupation city_category  \
# 0       1000004  P00128942      M  46-50           7             B
# 1       1000009  P00113442      M  26-35          17             C
# 2       1000010  P00288442      F  36-45           1             B
# 3       1000010  P00145342      F  36-45           1             B
# 4       1000011  P00053842      F  26-35           1             C
# ...         ...        ...    ...    ...         ...           ...
# 233594  1006036  P00118942      F  26-35          15             B
# 233595  1006036  P00254642      F  26-35          15             B
# 233596  1006036  P00031842      F  26-35          15             B
# 233597  1006037  P00124742      F  46-50           1             C
# 233598  1006039  P00316642      F  46-50           0             B
#
#        stay_in_current_city_years  marital_status  product_category_1  \
# 0                               2               1                   1
# 1                               0               0                   3
# 2                              4+               1                   5
# 3                              4+               1                   4
# 4                               1               0                   4
# ...                           ...             ...                 ...
# 233594                         4+               1                   8
# 233595                         4+               1                   5
# 233596                         4+               1                   1
# 233597                         4+               0                  10
# 233598                         4+               1                   4
#
#         product_category_2  product_category_3
# 0                     11.0                 NaN
# 1                      5.0                 NaN
# 2                     14.0                 NaN
# 3                      9.0                 NaN
# 4                      5.0                12.0
# ...                    ...                 ...
# 233594                 NaN                 NaN
# 233595                 8.0                 NaN
# 233596                 5.0                12.0
# 233597                16.0                 NaN
# 233598                 5.0                 NaN
#
# [233599 rows x 11 columns]

# %%
klib.pool_duplicate_subsets(df)
# Out:
#        product_id  pooled_vars
# 0       P00128942            0
# 1       P00113442            1
# 2       P00288442            2
# 3       P00145342            3
# 4       P00053842            4
# ...           ...          ...
# 233594  P00118942         3777
# 233595  P00254642        15537
# 233596  P00031842       233596
# 233597  P00124742       233597
# 233598  P00316642       233598
#
# [233599 rows x 2 columns]
